# %% [markdown]
# # <font color='blue'> Table Of Contents </font>
#
# ## <font color='blue'> Abstraction and Encapsulation </font>
#
# <font color='blue'>
#
# * Abstraction
#
# * Encapsulation
#
# * Exercise
#
# </font>
#
# ## <font color='blue'> Understanding Inheritance </font>
# <font color='blue'>
#
# * Concept with Example
# </font>

# %% [markdown]
# ### <font color='blue'> Abstraction </font>

# %% [markdown]
# To understand the concept of ***Abstraction*** in more details, let's try to define various attributes that can define a ***person.***

# %% [markdown]
# Refer below... and this can be an endless list.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Now consider that you are creating two applications. One for a restaurant and another one is a dating app.
# Both the applications have a user. Based on your understanding, categorise the attributes that are suitable for each application. Feel free to add a new attribute you feel is missing from the above list.

# %% [markdown]
# For restaurant it could be...
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# For dating app it could be...
# ![image.png](attachment:image.png)

# %% [markdown]
# **The question is what have we done here?**
# **Why have we done this? What purpose will this solve?**

# %% [markdown]
# Well... you just learnt the concept of abstraction.
# ***It is a process of removing or taking away the characteristics of any object (in general, and not a class object) that are not required and keeping the ones that are required at that point of time or for a required situation.***

# %% [markdown]
# ***These are the attributes of a class that we define for an application.***
# It is just one part of the task. The second part is we ***define the behavior*** of this class.
#
# This behavior is the list of functions (which we call methods) that we decide to write, which defines...
# 1. How the various states of an object is maintained.
# 2. How the objects of this class will interact with other objects within the application domain.
# 3. How the other objects in the application can interact with this object

# %% [markdown]
# One sample of restaurant application
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### <font color='blue'> Encapsulation </font>

# %% [markdown]
# Now, we will understand how the ***encapsulation*** fits in here.

# %% [markdown]
# In object-oriented programming (OOP), encapsulation refers to the bundling of data with the methods that operate on that data, or the restricting of direct access to some of an object's components.
# Encapsulation is used to hide the values or state of a structured data object inside a class, preventing direct access to them by clients in a way that could expose hidden implementation details or violate state invariance maintained by the methods
#
# <font size="1">Source Wikipedia</font>

# %% [markdown]
# And the concept of hiding the internal state of an object from other objects in an application is called ***Information hiding***

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <b>Note</b>: While defining the methods or behavior of a class, a programmer, defines these along with the access specifiers wherever needed. <br>
#     <b>_</b> for protected;  <b>__</b> for private. <br>
#     Yes, in Python these are recommendations. Yet, it is important to share the intent with programmers.
# </div>

# %% [markdown]
# ### <font color='blue'> Exercise </font>

# %% [markdown]
# As an exercise, I want all of you to identify and define other classes that should be part of an application for restaurant.
# For hint, you can think of a class ```Order```. This class will track each and every order placed. It can have the following...
# > This will contain the list of food items ordered.
# > Any discount on the overall bill.
# > Any dish given as a complement.
# > Any dish given at a discounted price.
# > Customer who ordered. (This can be a new or an existing customer).
# > Payment mode.
# > Number of people who consumed this order.
# > Order type - Dine-in or take-away.
# > feedback received.
# > Bearer who took the order.
# > Order amount  - based on MRP.
# > Final order amount - calculated after calculating discounts and complements.
# > You can think of many more things.
#
# Also think of various methods that you may need to Implement this order class.
# Feel free to think of other classes as well that you think are needed for this application to be complete.

# %% [markdown]
# ### <font color='blue'> Inheritance with example </font>

# %% [markdown]
# We have understood the concepts of Inheritance during the off-line sessions, now we will see one example to see how inheritance can be used in our applications.

# %% [markdown]
# Let us assume that we are preparing an application for a company that sells credit cards.
# And to lure a variety of customers we have a variety of cards at their disposal.
# The requirement is that we have to create classes for credit cards that are being sold at present.
# We have to design classes in such a way that, if required we should be able to use the existing classes to create new credit cards.
# ***For the sake of simplicity we will focus on the attributes that each card has.***

# %% [markdown]
# Let's collated the various attributes that defines "a credit card".
# Note - the class explains the purpose of each field. Practically one can assign some default values to these wherever
# applicable.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# So these are some of the attributes that defines a credit card. And these are common for any type of credit card.

# %% [markdown]
# Now we will use this CreditCard class as a base class to define more specialized cards. And this is where the inheritance
# comes in play. This is an example of simple inheritance.
# ![image.png](attachment:image.png)

# %% [markdown]
# Below is an another sample of simple inheritance.
# Since both CoralCard and GlobeTrotter inherit from the class CreditCard. This depicts a hierarchical inheritance.
# ![image.png](attachment:image.png)

# %% [markdown]
# Below is an example of multi-level and multiple inheritance
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
