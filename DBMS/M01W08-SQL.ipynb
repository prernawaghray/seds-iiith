# %% [markdown]
# <img src="http://drive.google.com/uc?export=view&id=1JzM1Jig5KAOCvU4tIf2t66B3gd1uy1rG" width=300px>
#
# Proprietary content. © Great Learning. All Rights Reserved. Unauthorized use or distribution prohibited.

# %% [markdown]
# # <font color='blue'> Table Of Contents </font>
#
# ## <font color='blue'> SQL
# * Prerequisite - <b><i>hr</i></b> database
# * Introduction
# * Entity Relationship - <b><i>hr</i></b> database
# * DML queries
# * Practice
# </font>

# %% [markdown]
# ### <font color='blue'> Structured Query Language (SQL) </font>

# %% [markdown]
# * SQL stands for Structured Query Language.
# * We use this language to manage data in a database.
# * This allows to manage the data using tables. And we write queries using this language to fetch the data.
# * All the DBs (MsSQL, MySQL, Oracle, DB2, PostgreSQL, etc) support this language.
# * It means that a query written on one DB will also work on other DB(s). Barring some extensions that are specific to DB(s).
# * This has been made possible as ISO made SQL a database standard.

# %% [markdown]
# #### <font color='blue'> Prerequisite </font>

# %% [markdown]
# To better understand the DML queries, specifically the SELECT, we will create a database in the name of ***hr.***
# The SQL file, ***hr-schema-mysql.sql,*** to create this database is already available on the Olympus for reference.
# The instruction for the installation of MySQL server has already been shared.
# ***Note***: You can install Workbench along with the MySQL server installation.
#
# And while working on this file I suggest you to go through and understand the DDL and DML statements in the file.
#
# For this session we will be using MySQL server and the Workbench application.
# You also ensure that you have MySQL server and the Workbench application installed on your machine.
# Have created the ***hr*** DB on the server and be able to execute basic queries on the ***hr*** or any existing DB.

# %% [markdown]
# #### <font color='blue'> Introduction </font>

# %% [markdown]
# In this session we will execute the DML queries, primarily ***SELECT*** statement(s) on the given database.
# This database will also help a learner to better understand the concept of...
# * ER Diagram
# * Primary keys, foriegn keys
# * DDL and DML operations
# * Joins and Subqueries

# %% [markdown]
# Beyond this point I go with an understanding that you have MySQL server and Workbench has been installed and ***hr*** database has been created.

# %% [markdown]
# #### <font color='blue'> ER (Entity Relationship) Diagram </font>

# %% [markdown]
# Let's have a look at the ER diagram of ***hr*** database.
# The fields highlighted in <font color='red'>RED</font> represent a primary key of it's corresponding table.
# The arrows in the diagram shows how the various entities (or tables) are associated with each other.

# %% [markdown]
# <img src="http://drive.google.com/uc?export=view&id=1X5u-NNHGFGt3R0A83GgyKwkrvc4d9cKC" width=1000px>

# %% [markdown]
# #### <font color='blue'> DML Queries </font>
# You must have got a file ***hr_select_statements.sql***, Now we will be going through various queries from this file to have a better grip on the ***SELECT*** statement and its various options.

# %% [markdown]
# #### <font color='blue'> Practice </font>
# Please refer to the file named as **SQL - MLS.pdf**. This file has a list of queries covering most of the concepts discussed. Please feel free to add your own set of examples with the existing set of queries.
#
# The file has two parts,
# ***Part A***: refers to DDL and DML queries and
# ***Part B*** refers to join operation and sub-queries related operation.
